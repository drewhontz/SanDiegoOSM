# %% [markdown]
# # San Diego Map Audit and Cleaning
#
# For Project 3 of the Data Analysis Nanodegree I have decided to look into my future home city of San Diego, CA. The following notebook will be broken up into these sections:
#
#     1 - Sampling
#     2 - General Audit
#     3 - Data Model
#     4 - Shaping
#     5 - Field Audits
#     6 - Cleaning Functions
#     7 - Final Preparations
#
# ## Section 1: Sampling
#
# The `san-diego_california.osm` file is approximately 303.8 MB large; while this is not overwhelmingly large, it is good practice to first work with a sample of your data to reduce processing time in the auditing and cleaning phases.
#
# Below is a snippet I borrowed from Udacity that will help us create our sample from the original file. The code block will investigate every k-th top level element that matches 'node', 'way', or 'relation' and write it (and it's children) out to an outfile named 'sample.osm'.

# %%
import xml.etree.cElementTree as ET
import pprint as pp
import os
import re
import json
from collections import defaultdict

# %%
OSM_FILE = "san-diego_california.osm"  # Replace this with your osm file
SAMPLE_FILE = "sample.osm"

k = 10 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %%
original_size = os.stat('san-diego_california.osm')
sample_size = os.stat('sample.osm')
print "Original file size:\t{}\nSample file size:\t{}".format(original_size.st_size, sample_size.st_size)
# Out:
# Original file size:	303838245
# Sample file size:	30821839

# %% [markdown]
# We can see that our sample file size is now approximately 30.8 MB in comparison to our 303.8 MB. This should be large enough to determine some cleaning rules and small enough that our functions will run quickly.

# %% [markdown]
# ## Section 2: General Audit
#
# Now that we have our sample, we should get a sense of what data is available to us. To do this, we will use a SAX parsing method (iterparse) to create a dictionary with tags and their counts to help determine which fields will be critical during our shaping phase.

# %%
def get_tag_frequencies(file_name):
    tag_freq = defaultdict(int)

    for ev, el, in ET.iterparse(file_name):
        if el.tag == 'node' or el.tag == 'way':
            for tag in el.iter('tag'):
                tag_freq[tag.get('k')] += 1
    return tag_freq

# %%
tag_freq = get_tag_frequencies('sample.osm')
print "{} unique tags in our data set\n".format(len(tag_freq))
pp.pprint(dict(tag_freq))
# Out:
# 433 unique tags in our data set
#
# {'ALAND': 1,
#  'AREAID': 1,
#  'AWATER': 1,
#  'FIXME': 17,
#  'MTFCC': 1,
#  'NHS': 44,
#  'Open_Date': 1,
#  'Tiger:MTFCC': 24,
#  'abutters': 3,
#  'access': 312,
#  'addr:city': 30820,
#  'addr:country': 34086,
#  'addr:county': 4,
#  'addr:full': 1,
#  'addr:housename': 26,
#  'addr:housenumber': 34425,
#  'addr:postcode': 30843,
#  'addr:state': 333,
#  'addr:street': 34432,
#  'addr:unit': 96,
#  'admin_level': 3,
#  'aerialway': 2,
#  'aeroway': 45,
#  'alt_name': 3,
#  'alt_name:el': 1,
#  'alt_name:es': 1,
#  'alt_name:fr': 1,
#  'alt_name:hi': 1,
#  'alt_name:ko': 1,
#  'alt_name:mn': 1,
#  'alt_name:tl': 1,
#  'alt_name:zh': 1,
#  'alt_name:zh_pinyin': 1,
#  'amenity': 669,
#  'amperage': 1,
#  'animal': 2,
#  'area': 35,
#  'area:highway': 1,
#  'artist_name': 1,
#  'artwork_type': 2,
#  'atm': 4,
#  'attraction': 2,
#  'attribution': 6,
#  'barrier': 134,
#  'baseball': 1,
#  'beach': 1,
#  'beacon': 12,
#  'beacon:colour': 9,
#  'beacon:text': 3,
#  'bench': 5,
#  'bicycle': 387,
#  'bicycle:lanes': 1,
#  'bicycle:lanes:backward': 1,
#  'bicycle:lanes:forward': 1,
#  'bicycle_parking': 1,
#  'border_type': 2,
#  'bottle': 3,
#  'boundary': 6,
#  'boundary_type': 1,
#  'brand': 4,
#  'brand:wikidata': 1,
#  'bridge': 145,
#  'building': 2306,
#  'building:height': 4,
#  'building:levels': 37,
#  'building:part': 2,
#  'building:use': 2,
#  'building_1': 1,
#  'building_type': 1316,
#  'buoy': 1,
#  'buoy:colour': 1,
#  'bus': 2,
#  'bus:toll': 2,
#  'button_operated': 7,
#  'cables': 7,
#  'caltrans:district': 4,
#  'caltrans:dynsegpm': 3,
#  'caltrans:pctuse': 1,
#  'caltrans:type': 3,
#  'capacity': 6,
#  'car': 1,
#  'census:population': 3,
#  'change:lanes': 8,
#  'change:lanes:backward': 1,
#  'change:lanes:forward': 2,
#  'charging_station:plug': 1,
#  'clothes': 3,
#  'collection_times': 2,
#  'construction': 3,
#  'construction_date': 1,
#  'contact:email': 1,
#  'contact:fax': 2,
#  'contact:phone': 3,
#  'contact:website': 3,
#  'contact:youtube': 1,
#  'content': 1,
#  'courts': 1,
#  'covered': 5,
#  'craft': 3,
#  'created_by': 1158,
#  'crossing': 165,
#  'crossing_ref': 1,
#  'csp:globalid': 2,
#  'csp:unitcode': 2,
#  'cuisine': 89,
#  'cutting': 1,
#  'cycleway': 241,
#  'cycleway:right': 3,
#  'dance:teaching': 1,
#  'delivery': 1,
#  'denomination': 50,
#  'denotation': 3,
#  'description': 29,
#  'description:en': 1,
#  'designation': 2,
#  'destination': 123,
#  'destination:ref': 17,
#  'destination:ref:to': 3,
#  'destination:street': 19,
#  'destination:street:to': 2,
#  'diet:vegan': 4,
#  'direction': 1,
#  'disused': 1,
#  'drive_in': 1,
#  'drive_through': 1,
#  'ele': 238,
#  'electrified': 10,
#  'embankment': 1,
#  'emergency': 12,
#  'enterance': 3,
#  'enterence': 1,
#  'entrance': 20,
#  'est_width': 1,
#  'exit_to': 29,
#  'fee': 15,
#  'fence_type': 1,
#  'fields': 2,
#  'fire_hydrant:type': 3,
#  'fixme': 48,
#  'food': 1,
#  'foot': 81,
#  'footway': 39,
#  'ford': 2,
#  'frequency': 10,
#  'fuel': 1,
#  'gauge': 1,
#  'generator:method': 1,
#  'generator:source': 1,
#  'gnis:Class': 12,
#  'gnis:County': 12,
#  'gnis:County_num': 12,
#  'gnis:ST_alpha': 12,
#  'gnis:ST_num': 12,
#  'gnis:county_id': 180,
#  'gnis:county_name': 31,
#  'gnis:created': 186,
#  'gnis:edited': 1,
#  'gnis:feature_id': 211,
#  'gnis:feature_type': 6,
#  'gnis:id': 12,
#  'gnis:import_uuid': 24,
#  'gnis:reviewed': 23,
#  'gnis:state_id': 180,
#  'golf': 16,
#  'healthcare': 3,
#  'heritage': 1,
#  'heritage:operator': 1,
#  'hgv': 118,
#  'hgv:national_network': 56,
#  'hgv:state_network': 12,
#  'highway': 6625,
#  'historic': 5,
#  'history': 11,
#  'hoops': 1,
#  'horse': 15,
#  'hov': 4,
#  'hov:toll': 2,
#  'import_uuid': 12,
#  'incline': 3,
#  'indoor': 1,
#  'information': 2,
#  'internet_access': 3,
#  'internet_access:fee': 1,
#  'is_in': 20,
#  'is_in:city': 782,
#  'is_in:country': 1037,
#  'is_in:country_code': 1034,
#  'is_in:state': 1035,
#  'is_in:state_code': 1036,
#  'kerb': 1,
#  'landuse': 121,
#  'lanes': 882,
#  'lanes:backward': 232,
#  'lanes:both_ways': 6,
#  'lanes:forward': 232,
#  'lanes:psv': 1,
#  'latitude': 24,
#  'layer': 173,
#  'lcn': 9,
#  'leaf_type': 42,
#  'leisure': 244,
#  'level': 7,
#  'light': 8,
#  'lit': 19,
#  'location': 225,
#  'longitude': 24,
#  'lot_no': 1,
#  'man_made': 71,
#  'maxspeed': 447,
#  'maxspeed:advisory': 7,
#  'maxspeed:hgv': 18,
#  'maxspeed:trailer': 21,
#  'military': 1,
#  'monitoring:water_level': 1,
#  'mooring': 3,
#  'motor_vehicle': 24,
#  'motor_vehicle:lanes': 1,
#  'motor_vehicle:lanes:backward': 1,
#  'motor_vehicle:lanes:forward': 1,
#  'motorcar': 5,
#  'motorcar:toll': 2,
#  'motorcycle': 2,
#  'name': 4065,
#  'name1': 1,
#  'name:de': 1,
#  'name:en': 4,
#  'name:es': 3,
#  'name:he': 1,
#  'name:hi': 1,
#  'name:ja': 1,
#  'name:ko': 1,
#  'name:lt': 1,
#  'name:pt': 1,
#  'name:ru': 2,
#  'name:uk': 1,
#  'name:vi': 1,
#  'name:zh': 2,
#  'name:zh_pinyin': 1,
#  'name_1': 52,
#  'name_base': 1,
#  'name_type': 1,
#  'natural': 222,
#  'nets': 9,
#  'network': 1,
#  'noexit': 2,
#  'note': 40,
#  'note:en': 1,
#  'note:highway': 1,
#  'note:ko': 1,
#  'note:lanes': 1,
#  'office': 5,
#  'old_name': 7,
#  'old_ref': 54,
#  'oneway': 1410,
#  'oneway:source': 1,
#  'oneway:source_ref': 1,
#  'opening_hours': 18,
#  'operator': 60,
#  'operator:phone': 1,
#  'outdoor_seating': 2,
#  'owner': 3,
#  'park:type': 2,
#  'park_ride': 5,
#  'parking': 25,
#  'parking:condition:left:time_interval': 3,
#  'parking:condition:right:time_interval': 3,
#  'parking:lane:both': 5,
#  'parking:lane:right': 1,
#  'parts': 1,
#  'payment:bitcoin': 1,
#  'payment:cash': 2,
#  'payment:e_zpass': 2,
#  'payment:e_zpass:name': 2,
#  'pet': 1,
#  'phone': 33,
#  'pipeline': 2,
#  'place': 20,
#  'placement': 3,
#  'population': 3,
#  'postal_code': 25,
#  'power': 543,
#  'proposed': 1,
#  'prosper:survey:poi': 2,
#  'prosper_poi_survey': 1,
#  'protect_class': 1,
#  'protection_title': 1,
#  'psv': 2,
#  'public_transport': 9,
#  'railway': 115,
#  'railway:proposed': 1,
#  'ref': 235,
#  'ref:right': 1,
#  'religion': 98,
#  'rental': 2,
#  'roof:colour': 1,
#  'roof:shape': 1,
#  'route': 7,
#  'sale': 2,
#  'sangis:BASENAME': 3,
#  'sangis:OBJECTID': 1300,
#  'sangis:TYPE': 1300,
#  'scooter': 1,
#  'seamark': 13,
#  'seamark:beacon_lateral:category': 5,
#  'seamark:beacon_lateral:colour': 5,
#  'seamark:beacon_lateral:system': 5,
#  'seamark:beacon_special_purpose:category': 4,
#  'seamark:beacon_special_purpose:colour': 5,
#  'seamark:buoy_lateral:category': 2,
#  'seamark:buoy_lateral:colour': 2,
#  'seamark:buoy_lateral:shape': 2,
#  'seamark:buoy_lateral:system': 2,
#  'seamark:buoy_special_purpose:category': 1,
#  'seamark:buoy_special_purpose:colour': 6,
#  'seamark:buoy_special_purpose:shape': 6,
#  'seamark:fog_signal:category': 2,
#  'seamark:fog_signal:period': 2,
#  'seamark:information': 1,
#  'seamark:light:character': 15,
#  'seamark:light:colour': 15,
#  'seamark:light:height': 7,
#  'seamark:light:period': 9,
#  'seamark:light:range': 6,
#  'seamark:name': 13,
#  'seamark:reference': 14,
#  'seamark:small_craft_facility:category': 1,
#  'seamark:topmark:colour': 9,
#  'seamark:topmark:colour_pattern': 4,
#  'seamark:topmark:shape': 9,
#  'seamark:type': 22,
#  'segregated': 4,
#  'service': 906,
#  'shelter': 3,
#  'shelter_type': 5,
#  'ship:type': 1,
#  'shop': 133,
#  'sidewalk': 288,
#  'smoking': 8,
#  'smoothness': 2,
#  'social_facility': 1,
#  'socket:tesla_supercharger': 1,
#  'source': 37126,
#  'source:addr': 2,
#  'source:bicycle': 2,
#  'source:hgv:national_network': 56,
#  'source:hgv:state_network': 12,
#  'source:lcn': 3,
#  'source:loc': 1,
#  'source:maxspeed': 267,
#  'source:maxspeed:advisory': 7,
#  'source:name': 12,
#  'source:pkey': 1,
#  'source:population': 1,
#  'source:website': 1,
#  'source_date': 3,
#  'source_ref': 14,
#  'sport': 90,
#  'start_date': 3,
#  'state': 1,
#  'stop': 8,
#  'substance': 1,
#  'substation': 2,
#  'supervised': 3,
#  'surface': 190,
#  'swing_gate:type': 1,
#  'takeaway': 4,
#  'test': 2,
#  'tiger:ALAND': 23,
#  'tiger:AREAID': 23,
#  'tiger:AWATER': 23,
#  'tiger:COUNTYFP': 23,
#  'tiger:STATEFP': 23,
#  'tiger:cfcc': 3118,
#  'tiger:county': 3136,
#  'tiger:name_base': 2716,
#  'tiger:name_base_1': 135,
#  'tiger:name_base_2': 11,
#  'tiger:name_direction_prefix': 220,
#  'tiger:name_direction_prefix_1': 8,
#  'tiger:name_direction_suffix': 14,
#  'tiger:name_type': 2468,
#  'tiger:name_type_1': 89,
#  'tiger:name_type_2': 7,
#  'tiger:reviewed': 2271,
#  'tiger:separated': 1445,
#  'tiger:source': 1601,
#  'tiger:tlid': 1599,
#  'tiger:upload_uuid': 430,
#  'tiger:zip_left': 2300,
#  'tiger:zip_left_1': 35,
#  'tiger:zip_left_2': 5,
#  'tiger:zip_left_3': 2,
#  'tiger:zip_left_4': 1,
#  'tiger:zip_right': 2247,
#  'tiger:zip_right_1': 23,
#  'tiger:zip_right_2': 1,
#  'tiger:zip_right_3': 2,
#  'time': 1,
#  'toll': 16,
#  'topmark': 9,
#  'tourism': 47,
#  'tower:type': 1,
#  'tracks': 1,
#  'tracktype': 2,
#  'traffic_calming': 32,
#  'traffic_sign': 14,
#  'traffic_signals': 6,
#  'tunnel': 19,
#  'turn:lanes': 368,
#  'turn:lanes:backward': 115,
#  'turn:lanes:both_ways': 6,
#  'turn:lanes:forward': 119,
#  'type': 14,
#  'url': 2,
#  'usage': 16,
#  'voltage': 31,
#  'water': 4,
#  'waterway': 27,
#  'website': 68,
#  'wetap:flow': 3,
#  'wetap:photo': 3,
#  'wetap:quality': 3,
#  'wetap:status': 4,
#  'wetap:statusnote': 1,
#  'wetap:temperature': 3,
#  'wetland': 5,
#  'wheelchair': 13,
#  'width': 2,
#  'wifi': 2,
#  'wikidata': 5,
#  'wikipedia': 8,
#  'wires': 5,
#  'zoo': 1}

# %% [markdown]
# 433 tags is a lot to handle but our analysis is not dependant on a lot of these fields.
#
# In our analysis later on, we will be looking mostly at address and amenity tag data so we will need to find which other tags relate to our interests from these 433. (Ex: we will be looking at the distribution of different types of fast food so we will need to clean the name and cuisine fields as well as amenity)
#
# In order to help narrow down which fields we will need to include in our data model, we should do the following 2 things:
#     - Settle on our final data model
#     - Create a list of tags we are interested in for later use in our shaping function

# %% [markdown]
# ## Section 3: Data Model

# %% [markdown]
# Below is the data model we will be using as provided by Udacity in the Data Analyst Nanodegree.
#
#     {
#         "id": "2406124091",
#         "type: "node",
#         "visible":"true",
#         "created": {
#                   "version":"2",
#                   "changeset":"17206049",
#                   "timestamp":"2013-08-03T16:43:42Z",
#                   "user":"linuxUser16",
#                   "uid":"1219059"
#                 },
#         "pos": [41.9757030, -87.6921867],
#         "address": {
#                   "housenumber": "5157",
#                   "postcode": "60625",
#                   "street": "North Lincoln Ave"
#                 },
#         "amenity": "restaurant",
#         "cuisine": "mexican",
#         "name": "La Cabana De Don Luis",
#         "phone": "1 (773)-271-5176"
#     }
#
# Some entries will not have all of these tags, some will have far more; these are the tags we will be using in our analysis later so these are what we will prioritize cleaning.
#
# **We will still retain entries that contain most of this data (like type, id, and our created fields) as well as the additional tags that we are not interested in at this time for potential later use.**
#
# One thing to mention is that our model will change if the type is 'way'. Ways are paths of some variety (trail, bike lane, street, etc) and while they may have some of the data above (such as all the 'created' fields) they are not likely to have definitive addresses or one [lat, lon] position.
#
# To accomodate for this we will add another field for 'way' types called 'node_refs' which will reference all the node id's which contain the lat, lon coordinates that define the way.
#
# The field will look as follows:
#
#     `"node_refs": [432432, 4332432, 432432, 454364],
#
# We already know all nodes have clean data for id, type, the created fields, and position as this is generally not human entered, so lets focus on our address information (housenumber, postcode, street, and city), phone, amenity type, and cuisine.
#
# To audit these fields, we will create each field a set containing all unique values associated with that field and fields that may potentially hold related values. (Ex: to create a set for the unique values associated with 'addr:postcode' we will probably want to look for postcode data in other fields with tags name 'zip')

# %% [markdown]
# ** Gathering our keys**
#
# In order to come up with the rules for generating the set's below, I first sorted our tag_freg list from above alphabetically by tag name, I scrolled through and wrote down keys that might be of interest.
#
# After I completed this list, I looked for potential to automate this since it was a pain to examine 433 unique keys. I found that the keys were generally self explanatory, if we are looking for housenumber data, typically the key had 'housenumber' in it's name even if it were prefixed by something like 'addr:' or 'tiger:'. One caveat was that 'city' yielded more keys than necessary, so I had to add an extra check to make sure 'capacity' was not added.
#
# Next I realized that since I would be parsing each tag in our sample data, I might as well add it's value to a set as well so that I could later glance at the unique values in our sample and derive cleaning rules for once our data is shaped.

# %%
housenumber = set()
house_keys = set()

postcode = set()
postcode_keys = set()

street = set()
street_keys = set()

city = set()
city_keys = set()

phone = set()
phone_keys = set()

amenity = set()
amenity_keys = set()

cuisine = set()
cuisine_keys = set()

for ev, el in ET.iterparse('sample.osm'):
        tag_list = el.iter('tag')
        if len(list(tag_list)) > 0:
            for tag in el.iter('tag'):
                tag_key = tag.get('k')
                tag_val = tag.get('v')
                if 'housenumber' in tag_key:
                    housenumber.add(tag_val)
                    house_keys.add(tag_key)
                if 'postcode' in tag_key or 'zip' in tag_key:
                    postcode.add(tag_val)
                    postcode_keys.add(tag_key)
                if 'street' in tag_key:
                    street.add(tag_val)
                    street_keys.add(tag_key)
                if 'city' in tag_key and (tag_key != 'capacity'):
                    city.add(tag_val)
                    city_keys.add(tag_key)
                if 'phone' in tag_key:
                    phone.add(tag_val)
                    phone_keys.add(tag_key)
                if 'amenity' in tag_key:
                    amenity.add(tag_val)
                    amenity_keys.add(tag_key)
                if 'cuisine' in tag_key:
                    cuisine.add(tag_val)
                    cuisine_keys.add(tag_key)

# %% [markdown]
# ## Section 4: Shaping
#
# Now that we have the keys we are interested in, I thought it wise to shape our data first before cleaning, as I find it easier to have consistent field names (i.e. our zip code data will be in address.postcode rather than zip_1, zip_2, and addr:zip_1) when cleaning similar fields of data.

# %%
def shape_data(map_file):
    master = []
    for ev, el in ET.iterparse(map_file):  
        if el.tag == 'node' or el.tag == 'way':
            node = {}
            node['id'] = el.get('id')
            node['type'] = el.tag
            if node['type'] == 'node':
                node['pos'] = [el.get('lat'), el.get('lon')]
            node['created'] = {'version': el.get('version'),\
                               'changeset': el.get('changeset'), 'user': el.get('user'),\
                               'uid': el.get('uid'), 'timestamp': el.get('timestamp')}
            node['address'] = {}
            for tag in el.iter('tag'):
                key = tag.get('k')
                if key in city_keys:
                    node['address']['city'] = tag.get('v')
                if key in house_keys:
                    node['address']['housenumber'] = tag.get('v')
                if key in postcode_keys:
                    node['address']['postcode'] = tag.get('v')
                if key in street_keys:
                    node['address']['street'] = tag.get('v')
                if key in phone_keys:
                    node['phone_number'] = tag.get('v')
                elif key[:4] != 'addr':
                    node[key] = tag.get('v')
            if node['type'] == 'way':
                node['node_refs'] = []
                for nd in el.iter('nd'):
                    node['node_refs'].append(nd.get('ref'))
            if len(node['address'].keys()) == 0:
                del node['address']
            master.append(node)
    return master

# %%
sample = shape_data('sample.osm')

# %% [markdown]
# Our data is now shaped, so let's start our field audits and move into cleaning.

# %% [markdown]
# ## Section 5: Field Audits and Cleaning Functions
#
# We already have all of our unique entries for the fields we need to audit stored in a set from our key gathering process so let's take a look at each one and determine our cleaning rules before we write our cleaning functions
#
# We will look at the following fields:
#
#     1 - City name
#     2 - Postcode
#     3 - Housenumber
#     4 - Streetname
#     5 - Phone number
#     6 - Amenity name/type
#     7 - Cuisine
#     8 - Fast Food Names
#     9 - Place of Worship
#
# Since the goal of this cleaning process is to produce a quality data product, let's remind ourselves of the dimensions of quality data to remind us of what to look for in our audit.
#
# ** Completeness, Consistency, Accuracy, Validity, Uniformity. **

# %% [markdown]
# ### 5.1 City Name

# %%
for item in city:
    print item
# Out:
# Bonita
# Santee
# Lemon Grove
# Lakeside
# San Ysidro
# San Diego
# El Cajon
# La Mesa
# Coronado
# Imperial Beach
# La Jolla
# National City
# Spring Valley
# Chula Vista

# %% [markdown]
# Great news, nothing to clean here, these are all valid, complete, accurate cities within the San Diego city limit! Lets move on.

# %% [markdown]
# ### 5.2 Postcode

# %%
for pc in postcode:
    print pc
# Out:
# 92113
# 91942
# 91941
# 91902
# 91945
# 92093
# 92010-1407
# 92110-9998
# 92121
# 92120
# 92123
# 92122
# 92124
# 92071
# 92126
# 92107
# 92106
# 92105
# 92104
# 92103
# 92102
# 92101
# 92092
# 91941:91945
# 91935
# 92037
# 91932
# 92140
# 92019
# 92145
# 92182
# 92118
# 91977
# 91950
# 91911
# 91910
# 91913
# 91978
# 91915
# 91914
# 92104:92116
# 92129
# 92110; 92109
# 92105:92116
# 91950:92113
# 92065
# 92154
# 92119
# 92131
# 92136
# 92109
# 92135
# 92110
# 92111
# 92139
# 92114
# 92115
# 92116
# 92117
# 92108
# 92114; 92102
# 91935:91978
# 92040
# 92173
# 92020
# 92021
# 92022

# %% [markdown]
# We have some minor problems with postcodes here. While these values are all within the San Diego city limits, we have some values in the format XXXXX-XXXX and some that express a range of values for our ways that span multiple postal codes.
#
# **Cleaning Rules**
#  - If an entry contains a '-' character, split the value at '-' and retain the first 5 digits
#  - If an entry contains a ':' (denoting a range) fill in the range of postal codes between the two numbers and store the postal code as a list of those values

# %%
def clean_postcode(map_dict):
    for entry in map_dict:
        if 'address' in entry.keys():
            if 'postcode' in entry['address'].keys():
                if len(entry['address']['postcode']) > 5:     
                    if '-' in entry['address']['postcode']:
                        print  "{} becomes {}".format(entry['address']['postcode'], entry['address']['postcode'][:5]) 
                        entry['address']['postcode'] = entry['address']['postcode'][:5]
                        
                    if ':' in entry['address']['postcode']:
                        zip_range = entry['address']['postcode'].split(':')                       
                        print "{} becomes {}".format(entry['address']['postcode'], range(int(zip_range[0]), int(zip_range[1])))
                        entry['address']['postcode'] = range(int(zip_range[0]), int(zip_range[1]))

# %% [markdown]
# ### 5.3 Housenumber

# %%
for number in housenumber:
    if not number.isdigit():
        print number
# Out:
# 180 1/2
# 671 1/2
# 3663 1/2
# 3736 1/2
# 10431;10433
# 10503;10505
# 9454 1/2
# 4951 1/2
# 815 1/2
# 1624 1/2
# 4426-4440
# 1408 E
# 4936 1/2
# 970 1/2
# 524 1/2
# 3926 1/2
# 3387 .5
# 1855 1/2
# 8764 1/2
# 265 1/2
# 8802 .5
# 7735 1/2
# 1752 1/2
# 10747;10749
# 6995 1/2
# 4863 1/2
# 11976 1/2
# 513 1/2
# 2396 1/2
# 723 1/2
# 2410 1/2
# 9044 .5
# 12343 1/2
# 1417 E
# 124 1/2
# 4630 1/2
# 27 1/2
# 3446 1/2
# 8932 1/2

# %% [markdown]
# There were far too many house numbers to audit with my own eye and there are very vague rules on what house numbers (that are purely digits) are valid (ex: your house can be 111 or 6666666 and it can still be valid) so I decided for our audit, we would only look that those house numbers with non digit characters in them.
#
# Below are the cleaning rules
#
# Cleaning rules:
# - Convert all '.5' addresses to the valid 1/2 format
# - Entries with ';' characters express buildings with a range of addresses within. Fill in the values in this range and store as a list

# %%
def clean_housenumber(map_dict):
    for entry in map_dict:
        if 'address' in entry.keys():
            if 'housenumber' in entry['address'].keys():
                if '.5' in entry['address']['housenumber']:
                    print "{} becomes {}".format(entry['address']['housenumber'], entry['address']['housenumber'].replace('.5', '1/2'))
                    entry['address']['housenumber'] = entry['address']['housenumber'].replace('.5', '1/2')
                    
                if ';' in entry['address']['housenumber']:
                    house_range = entry['address']['housenumber'].split(';')
                    start = int(house_range[0])
                    end = int(house_range[1])
                    if start > end:
                        rng = range(end, start)
                    else:
                        rng = range(start, end)
                    print "{} becomes {}".format(entry['address']['housenumber'], rng)
                    entry['address']['housenumber'] = rng

# %% [markdown]
# ### 5.4 Street Name

# %%
def get_road_types(road_names):
    road_type = set()
    for name in road_names:
        n = name.split()
        road_type.add(n[len(n) - 1])
    return road_type

def get_road_prefix(road_names):
    pre = set()
    for name in road_names:
        pre.add(name.split()[0])
    return pre

road_types = get_road_types(street)
road_prefix = get_road_prefix(street)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-14-c367d5b03e63> in <module>()
#      12     return pre
#      13
# ---> 14 road_types = get_road_types(street)
#      15 road_prefix = get_road_prefix(street)
#
# NameError: name 'street' is not defined

# %%
for rt in road_types:
    if len(rt) < 4:
        print rt
# Out:
# Rey
# Oro
# Fe
# Eva
# St
# Ln
# Rd
# Pan
# Dr
# Rio
# Py
# Pl
# #A
# Way
# 67
# Paz
# Ct
# Sol
# Ic
# Sur
# Lee
# Row
# Ave
# Mar
# Av

# %%
for pre in road_prefix:
    if len(pre) < 3:
        print pre
# Out:
# Le
# A
# B
# D
# Z
# Mc
# E
# Hi
# My
# La
# F
# G
# Di
# De
# H
# T
# C
# I
# N.
# J
# St
# L
# El
# M
# N
# O
# Q
# R
# K

# %% [markdown]
# In order to audit street names I looked immediately for problem areas like cardinal direction abbreviations in the first and last word in a street name string as well as abbreviations in the last word of the string (St., Rd., etc)
#
# Rules
#  - In our prefix, we will need to clean out values smaller than 3 characters long with a '.'.
#  - In our suffix, we will need to clean out values matching 'Av, Ave, Ct, Pl, Dr, Ln, St'

# %%
def clean_street(data):
    error = {
        'Ave' : "Avenue",
        'St' : "Street",
        "Ln" : "Lane",
        "Av" : "Avenue",
        'Pl' : "Place",
        "Dr" : "Drive",
        "Dr." : "Drive",
        'Rd' : "Road",
        "Ct" : "Court",
        "Rd." : "Road",   
    }
    for entry in data:
        if 'address' in entry.keys():
            if 'street' in entry['address'].keys():
                name = entry['address']['street'].split()
                if name[len(name) - 1] in list(error.keys()):
                    name[len(name) - 1] = error[name[len(name) - 1]]
                    new_value = " ".join(map(str, name))
                    print "{} becomes {}".format(entry['address']['street'], new_value)
                    entry['address']['street'] = new_value

# %% [markdown]
# ### 5.5 Phone Number

# %%
for num in phone:
    print num
# Out:
# 6192371245
# 619-223-8171
# 877-268-8822
# 8584539383
# +1 858 5654807
# 619-255-4425
# 18583611280
# +1 619 448 0899
# +1-619-831-0225
# +1 858-693-3500
# +1 619 234 0425
# (858) 404-0701
# 619-688-0170
# (619)575-4421
# +1 619 2555147
# 619-422-4141
# 619-929-0461
# +16197250850
# 855-680-3238
# 619-476-3763
# (619)228-9881
# +16192827283
# 619-594-5200
# 619-265-2099
# 619-294-2074
# +619-692-4910
# 619.264.2072
# 8585767466
# +1 858 457 5593
# 619-260-8024
# 619-209-3554
# +18585604551
# +1-619-231-4040
# 619-645-3057
# +1-619-239-5548
# 619-291-2900
# +18585651288
# 619-297-8800

# %% [markdown]
# Cleaning rules:
#  - Remove all non digit characters (i.e. periods, plus sign, parentheses, dashes, etc)
#  - Take the length of the phone number, those fewer than 10 digits xxx xxx xxxx (without spaces) should be removed
#  - If the phone number has a leading 1, remove it
#  - insert a '-' character after the 3rd and 6th digit for the xxx-xxx-xxxx format

# %%
def clean_phone(map_dict):
    for entry in map_dict:
        if 'phone_number' in entry.keys():
            entry['phone_number'] = re.sub('[^0-9]','', entry['phone_number'])
            if len(entry['phone_number']) < 10:
                print "Removing {}".format(entry['phone_number'])
                del entry['phone_number']
            else:
                if entry['phone_number'][0] == '1':
                    entry['phone_number'] = entry['phone_number'][1:]
                formatted = entry['phone_number'][0:3] + '-' + entry['phone_number'][3:6] + '-' + entry['phone_number'][6:]
                print "{} becomes {}".format(entry['phone_number'], formatted)
                entry['phone_number'] = formatted

# %% [markdown]
# ### 5.6 Amenity

# %%
for a in sorted(amenity):
    print a
# Out:
# arts_centre
# atm
# bank
# bar
# bench
# bicycle_parking
# cafe
# car_rental
# car_wash
# charging_station
# cinema
# clinic
# coast_guard
# college
# compressed_air
# concert_hall
# dentist
# dojo
# drinking_water
# emergency_phone
# fast_food
# fire_station
# fountain
# fuel
# hospital
# library
# mall
# parking
# parking_entrance
# parking_space
# pet
# pharmacy
# picnic_table
# place_of_worship
# police
# post_box
# post_office
# preschool
# pub
# recycling
# restaurant
# school
# shelter
# swimming_pool
# theatre
# toilets
# university
# waste_basket
# waste_disposal

# %% [markdown]
# All our amenity data looks like it is in good shape. I might have some arguments as to what should constitute an amenity but that is a gripe with OpenStreetMaps. Lets move on.

# %% [markdown]
# ### 5.7 Cuisine

# %%
for c in sorted(cuisine):
    print c
# Out:
# Dining_Hall
# american
# asian_fusion
# bagel
# breakfast
# burger
# cafeteria
# chicken
# chinese
# chinese;japanese
# coffee_shop
# french;sandwich
# funnel_cake
# ice_cream
# italian
# japanese
# juice
# kebab
# mexican
# noodle
# pizza
# pretzels
# sandwich
# thai
# vegan
# yogurt

# %% [markdown]
# Note: Some entries in our data set are not fast food but retain the cuisine field (if the amenity is a restaurant, it is likely to have a cuisine field) we will clean these values even if we are not intending to use them in our analysis
#
# Cleaning rules:
# - If the first letter is capital, replace it with a lowercase
# - If ';' or ',' is in the entry, split it and store as a list
# - strip any whitespace cause by list splits
# - strip _shop, _house from entries
# - change 'india' values to 'indian'
# - pluralize 'burger'and 'pretzel'
# - any variation on donut (doughnut, doughnuts) should be donuts

# %%
import unicodedata

# convenience function for cleaning cuisine types that will be broken out into a list
def clean_list_values(val):
    if "_" in val:
        val = val.strip("_")
    if " " in val:
        val = val.strip(" ")
    return val

def clean_cuisine(map_dict):
    for entry in map_dict:
        if 'cuisine' in entry.keys():
            if isinstance(entry['cuisine'], list):
                print "Already cleaned!"
                break
            cuisine = entry['cuisine'].lower()
            if isinstance(entry['cuisine'], unicode):
                cuisine = unicodedata.normalize('NFKD', cuisine).encode('ascii','ignore')
                print "Unicode becomes {}".format(cuisine)
            if "_shop" in cuisine:
                val = cuisine[:-5]
                print "{} becomes {}".format(cuisine, val)
                cuisine = val
            if "_house" in cuisine:
                val = cuisine[:-6]
                print "{} becomes {}".format(cuisine, val)
                cuisine = val
            if "india" == cuisine:
                val = "indian"
                print "{} becomes {}".format(cuisine, val)
                cuisine = val
            if "nut" in cuisine:
                val = "donuts"
                print "{} becomes {}".format(cuisine, val)
                cuisine = val
            if "pretzel" == cuisine:
                val = "pretzels"
                print "{} becomes {}".format(cuisine, val)
                cuisine = val
            if "burger" in cuisine and 'burgers' not in cuisine:
                val = cuisine.replace('burger', 'burgers')
                print "{} becomes {}".format(cuisine, val)
                cuisine = val
            if ";" in cuisine:
                val = cuisine.split(';')
                print "{} becomes {}".format(cuisine, val)
                cuisine = val  
            if "," in cuisine:
                val = cuisine.split(',')
                val = map(clean_list_values, val)
                print "{} becomes {}".format(cuisine, val)
                cuisine = val 
            entry['cuisine'] = cuisine

# %% [markdown]
# ### 5.8 Fast Food Names

# %% [markdown]
# Since the `name` field can be used to describe the name of any node, way, or tag, I decided to take a different approach to finding our unique values (as opposed to adding them to a set when parsing tags earlier, I pull them from our shaped data).
#
# Lets take a look at what our fast food names look like

# %%
def get_set_of_ff_names(data):
    ff_names = set()

    for row in data:
        if 'amenity' in row.keys():
            if row['amenity'] == "fast_food" and 'name' in row.keys():
                ff_names.add(row['name'])
    return ff_names

# %%
ff_names = get_set_of_ff_names(sample)
pp.pprint(ff_names)
# Out:
# set(['All Fried Up',
#      'Arbys',
#      'Burger King',
#      'Carls Jr.',
#      'Chipotle',
#      "Coco's Restaurant",
#      'Cold Stone Creamery',
#      'Craft Pizza Company',
#      "Daphne's California Greek",
#      'Del Taco',
#      'Dominos Pizza',
#      'Einstein Bros. Bagels',
#      'Fins Mexican Eatery',
#      'Five Guys Burgers and Fries',
#      'Fortune Cookie Express',
#      'IHOP Express',
#      'In N Out Burger',
#      'In-N-Out Burger',
#      'Jack In The Box',
#      'Jack in the Box',
#      'KFC',
#      'Kebab Grill',
#      "Little Caesar's Pizza",
#      'Los Primos Mexican Food',
#      'Lucha Libre Gourmet Taco Shop',
#      "McDonald's",
#      "Oggi's Pizza Express",
#      'Panda Express',
#      'Papa Johns',
#      'Pizza Hut',
#      "Rubio's Baja Grill",
#      'Subway Sandwiches',
#      'Taco Bell',
#      'Via Moto',
#      "Wendy's",
#      "Wetzel's Pretzels"])

# %% [markdown]
# It looks like we are going to have a lot of similar values to be cleaned (see Jack in the Box and In-N-Out) I will want to have a means of identifying what needs to be cleaned programatically when we apply this to the full data set. To do so, I will simply filter out those who have the first 4 characters in common. This isn't perfect and I can already see it impacting places that start with 'The ' but it is a quick way to reduce the set that needs to be cleaned to a size that I can manually scrub.

# %%
def create_list_of_names_to_clean(set_data):
    name_clean = []
    data = sorted(list(set_data))
    for x in range(1, len(data)):
        cur_name = data[x]
        prev_name = data[x - 1]
        if cur_name[:4] == prev_name[:4]:
            name_clean.append(cur_name)
    return name_clean

# %%
to_clean = create_list_of_names_to_clean(ff_names)
pp.pprint(to_clean)
# Out:
# ['Jack in the Box']

# %% [markdown]
# As we can see from the results above, this did not do an excellent job at filtering as it missed our only other similar value (In n out). I will still keep this method around as I don't expect the number of franchises to grow (although I do anticipate more of the current values will have different spellings) this is an extremely manual means of cleaning but that is just a part of cleaning sometimes.
#
# **Edit** When I applied this to the full data set, my filter method generated a much larger list. I worked my way through this list, identified a regular expression that would target these issues, compiled it into the dictionary you see below and formed the cleaning function.

# %%
def clean_fast_food_entries(data):
    regex_dict = {
    "^Arby": "Arby's",
    "^Bombay" : "Bombay Coast Indian Tandoor & Curry Express",
    ".Green" : "Carl's Jr. / The Green Burrito",
    "^Carl.*(r|\.)$": "Carl's Jr.",
    "^Chipo" : "Chipotle Mexican Grill",
    "^Daphn" : "Daphne's California Greek Restaurant",
    "(Wiene)" : "Wienerschnitzel",
    "^Papa" : "Papa John's Pizza",
    "^Rubio" : "Rubio's Coastal Grill",
   "^Little" : "Little Caesars",
    "^Pick" : "Pick Up Stix",
   "^Jack" : "Jack in the Box",
    "^In" : "In-N-Out Burger",
    "^Five" : "Five Guys Burger and Fries",
    "^Evolution": "Evolution Fast Food",
    "^Jersey" : "Jersey Mike's Subs",
    "^Roberto" : "Roberto's Taco Shop",
    "^Santan" : "Fresh MXN Food",
    "^Subway" : "Subway",
    "^Wahoo" : "Wahoo's Fish Taco",
    "^Z" : "Zpizza"
    }
    
    for key in regex_dict.keys():
        for entry in data:
            if 'name' in entry.keys():
                if 'amenity' in entry.keys():
                    if entry['amenity'] ==  'fast_food':
                        rgx = re.compile(key)
                        if re.search(rgx, entry['name']):
                            print "{} becomes {}".format(entry['name'], regex_dict[key])
                            entry['name'] = regex_dict[key]

# %% [markdown]
# ### 5.9 Places of Worship

# %% [markdown]
# I wanted to get a measure of the religious presence is in San Diego mostly to compare the number of churches to my current home in Seattle, WA. Below are the audit and cleaning functions.

# %%
def get_places_of_worship(data):
    worship_set = set()
    for entry in data:
        if 'amenity' in entry.keys():
            if entry['amenity'] == 'place_of_worship':
                if 'religion' in entry.keys():
                    worship_set.add(entry['religion'])
    return worship_set

# %%
get_places_of_worship(sample)
# Out:
# {'christian', 'jewish', 'muslim'}

# %% [markdown]
# Our sample only returns 3 distinct religions in San Diego and I found that hard to believe so I tested it on our master set later on. The data was in good shape so the only change I made was to lump the values 'unitarian_universal' in the unitarian bucket

# %%
def clean_religion(data):
    for entry in data:
        if 'amenity' in entry.keys():
            if entry['amenity'] == 'place_of_worship':
                if 'religion' in entry.keys():
                    if 'unitarian_' in entry['religion']:
                        entry['religion'] = 'unitarian'

# %% [markdown]
# ### Master cleaning function
#
# Here is a convenience function for cleaning our data at once

# %%
def clean_all(data):
    print "1/6 Cleaning postcode data"
    clean_postcode(data)

    print "\n2/7 Cleaning house number data"
    clean_housenumber(data)
    
    print "\n3/7 Cleaning street name data"
    clean_street(data)
    
    print "\n4/7 Cleaning phone data"
    clean_phone(data)
    
    print "\n5/7 Cleaning cuisine data"
    clean_cuisine(data)

    print "\n6/7 Cleaning fast food name data"
    clean_fast_food_entries(data)

    print "\n7/7 Cleaning religion data"
    clean_religion(data)
    
    print "All clean"

# %% [markdown]
# # Cleaning, Shaping, and JSON-ifying our final output
#
# Now that we have a sense of what is in our map data, lets apply all the cleaning functions we derived from our sample to our original map file.
# We will start by shaping the data to a python dictionary, calling our cleaning functions one-by-one, then writing this dictionary out to a JSON file.
#
# Finally when our file is formed, we will upload it to our instance of MongoDB!

# %%
master =  shape_data('san-diego_california.osm')

# %%
clean_all(master)
# Out:
# 1/6 Cleaning postcode data
# 92037-4291 becomes 92037
# 92010-1407 becomes 92010
# 92071-4417 becomes 92071
# 92108-3803 becomes 92108
# 92103-3607 becomes 92103
# 92103-3609 becomes 92103
# 92103-3609 becomes 92103
# 92110-9998 becomes 92110
# 92093-0094 becomes 92093
# 92101-6144 becomes 92101
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 91942:92119 becomes [91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977, 91978, 91979, 91980, 91981, 91982, 91983, 91984, 91985, 91986, 91987, 91988, 91989, 91990, 91991, 91992, 91993, 91994, 91995, 91996, 91997, 91998, 91999, 92000, 92001, 92002, 92003, 92004, 92005, 92006, 92007, 92008, 92009, 92010, 92011, 92012, 92013, 92014, 92015, 92016, 92017, 92018, 92019, 92020, 92021, 92022, 92023, 92024, 92025, 92026, 92027, 92028, 92029, 92030, 92031, 92032, 92033, 92034, 92035, 92036, 92037, 92038, 92039, 92040, 92041, 92042, 92043, 92044, 92045, 92046, 92047, 92048, 92049, 92050, 92051, 92052, 92053, 92054, 92055, 92056, 92057, 92058, 92059, 92060, 92061, 92062, 92063, 92064, 92065, 92066, 92067, 92068, 92069, 92070, 92071, 92072, 92073, 92074, 92075, 92076, 92077, 92078, 92079, 92080, 92081, 92082, 92083, 92084, 92085, 92086, 92087, 92088, 92089, 92090, 92091, 92092, 92093, 92094, 92095, 92096, 92097, 92098, 92099, 92100, 92101, 92102, 92103, 92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115, 92116, 92117, 92118]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 92093-0068 becomes 92093
# 92105:92116 becomes [92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92102-4810 becomes 92102
# 92111-2201 becomes 92111
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 92101-3414,  becomes 92101
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 91935:91978 becomes [91935, 91936, 91937, 91938, 91939, 91940, 91941, 91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977]
# 91935:91978 becomes [91935, 91936, 91937, 91938, 91939, 91940, 91941, 91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977]
# 91935:91978 becomes [91935, 91936, 91937, 91938, 91939, 91940, 91941, 91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977]
# 91935:91978 becomes [91935, 91936, 91937, 91938, 91939, 91940, 91941, 91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977]
# 91935:91978 becomes [91935, 91936, 91937, 91938, 91939, 91940, 91941, 91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977]
# 91935:91978 becomes [91935, 91936, 91937, 91938, 91939, 91940, 91941, 91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977]
# 91935:91978 becomes [91935, 91936, 91937, 91938, 91939, 91940, 91941, 91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977]
# 91935:91978 becomes [91935, 91936, 91937, 91938, 91939, 91940, 91941, 91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977]
# 91935:91978 becomes [91935, 91936, 91937, 91938, 91939, 91940, 91941, 91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977]
# 91935:91978 becomes [91935, 91936, 91937, 91938, 91939, 91940, 91941, 91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977]
# 91935:91978 becomes [91935, 91936, 91937, 91938, 91939, 91940, 91941, 91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977]
# 91935:91978 becomes [91935, 91936, 91937, 91938, 91939, 91940, 91941, 91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977]
# 91935:91978 becomes [91935, 91936, 91937, 91938, 91939, 91940, 91941, 91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977]
# 91935:91978 becomes [91935, 91936, 91937, 91938, 91939, 91940, 91941, 91942, 91943, 91944, 91945, 91946, 91947, 91948, 91949, 91950, 91951, 91952, 91953, 91954, 91955, 91956, 91957, 91958, 91959, 91960, 91961, 91962, 91963, 91964, 91965, 91966, 91967, 91968, 91969, 91970, 91971, 91972, 91973, 91974, 91975, 91976, 91977]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 92104:92116 becomes [92104, 92105, 92106, 92107, 92108, 92109, 92110, 92111, 92112, 92113, 92114, 92115]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 91941:91945 becomes [91941, 91942, 91943, 91944]
# 92111-2201 becomes 92111
#
# 2/7 Cleaning house number data
# 5558;5556 becomes [5556, 5557]
# 3387 .5 becomes 3387 1/2
# 1642 .5 becomes 1642 1/2
# 8846 .5 becomes 8846 1/2
# 1832 .5 becomes 1832 1/2
# 9044 .5 becomes 9044 1/2
# 8802 .5 becomes 8802 1/2
# 8848 .5 becomes 8848 1/2
# 10678;10674 becomes [10674, 10675, 10676, 10677]
# 10682;10686 becomes [10682, 10683, 10684, 10685]
# 10730;10734 becomes [10730, 10731, 10732, 10733]
# 10722;10726 becomes [10722, 10723, 10724, 10725]
# 10531;10533 becomes [10531, 10532]
# 10527;10529 becomes [10527, 10528]
# 10503;10505 becomes [10503, 10504]
# 10523;10525 becomes [10523, 10524]
# 10507;10509 becomes [10507, 10508]
# 10519;10521 becomes [10519, 10520]
# 10511;10513 becomes [10511, 10512]
# 10515;10517 becomes [10515, 10516]
# 10431;10433 becomes [10431, 10432]
# 10427;10429 becomes [10427, 10428]
# 10407;10409 becomes [10407, 10408]
# 10419;10421 becomes [10419, 10420]
# 10431;10433 becomes [10431, 10432]
# 10427;10429 becomes [10427, 10428]
# 10403;10405 becomes [10403, 10404]
# 10423;10425 becomes [10423, 10424]
# 10763;10768 becomes [10763, 10764, 10765, 10766, 10767]
# 10759;10761 becomes [10759, 10760]
# 10735;10737 becomes [10735, 10736]
# 10755;10757 becomes [10755, 10756]
# 10739;10741 becomes [10739, 10740]
# 10751;10753 becomes [10751, 10752]
# 10743;10745 becomes [10743, 10744]
# 10747;10749 becomes [10747, 10748]
# 855;865 becomes [855, 856, 857, 858, 859, 860, 861, 862, 863, 864]
#
# 3/7 Cleaning street name data
# Cornerstone Ct becomes Cornerstone Court
# Cornerstone Ct becomes Cornerstone Court
# Lyman Ln becomes Lyman Lane
# Shelter Island Dr. becomes Shelter Island Drive
# S Greensview Dr becomes S Greensview Drive
# W Mission Bay Dr becomes W Mission Bay Drive
# 10th Ave becomes 10th Avenue
# 1710 W Mission Bay Dr becomes 1710 W Mission Bay Drive
# 500 Sea World Dr becomes 500 Sea World Drive
# Genesee Av becomes Genesee Avenue
# Dennery Rd becomes Dennery Road
# Ronson Rd becomes Ronson Road
# Harbor Island Dr becomes Harbor Island Drive
# Dairy Mart Rd becomes Dairy Mart Road
# Dennery Rd becomes Dennery Road
# Mildred St becomes Mildred Street
# Dennery Rd becomes Dennery Road
# Dairy Mart Rd becomes Dairy Mart Road
# Gateway Center Av becomes Gateway Center Avenue
# W Cedar St becomes W Cedar Street
# Complex Dr becomes Complex Drive
# Genesee Av becomes Genesee Avenue
# Pearl St becomes Pearl Street
# Starling Dr becomes Starling Drive
# Raytheon Rd becomes Raytheon Road
# J St becomes J Street
# Ohio St becomes Ohio Street
# Fay Ave becomes Fay Avenue
# Diza Rd becomes Diza Road
# Athey Av becomes Athey Avenue
# C St becomes C Street
# C St becomes C Street
# Genesee Av becomes Genesee Avenue
# Murray Dr becomes Murray Drive
# Murray Dr becomes Murray Drive
# Grossmont Center Dr becomes Grossmont Center Drive
# Grossmont Center Dr becomes Grossmont Center Drive
# Orange Ave becomes Orange Avenue
# Orange Ave becomes Orange Avenue
# Avocado School Rd becomes Avocado School Road
# Fury Ln becomes Fury Lane
# Center Dr becomes Center Drive
# Jamacha Rd becomes Jamacha Road
# Jamacha Rd becomes Jamacha Road
# Jamacha Rd becomes Jamacha Road
# Jamacha Rd becomes Jamacha Road
# N Magnolia Av becomes N Magnolia Avenue
# N Magnolia Av becomes N Magnolia Avenue
# Amaya Dr becomes Amaya Drive
# Navajo Rd becomes Navajo Road
# Navajo Rd becomes Navajo Road
# Navajo Rd becomes Navajo Road
# Navajo Rd becomes Navajo Road
# Murray Dr becomes Murray Drive
# Murray Dr becomes Murray Drive
# Murray Dr becomes Murray Drive
# Murray Dr becomes Murray Drive
# Murray Dr becomes Murray Drive
# Jamacha Rd becomes Jamacha Road
# Jamacha Rd becomes Jamacha Road
# Jamacha Rd becomes Jamacha Road
# Jamacha Rd becomes Jamacha Road
# Jamacha Rd becomes Jamacha Road
# Campo Rd becomes Campo Road
# Jamacha Rd becomes Jamacha Road
# Jamacha Rd becomes Jamacha Road
# Grossmont Center Dr becomes Grossmont Center Drive
# Judicial Dr becomes Judicial Drive
# Smythe Av becomes Smythe Avenue
# Radcliffe Dr becomes Radcliffe Drive
# Arlette St becomes Arlette Street
# Jamacha Rd becomes Jamacha Road
# Jamacha Rd becomes Jamacha Road
# Jamacha Rd becomes Jamacha Road
# Fury Ln becomes Fury Lane
# Jamacha Rd becomes Jamacha Road
# Sweetwater Rd becomes Sweetwater Road
# Sweetwater Rd becomes Sweetwater Road
# 4300 Taylor St becomes 4300 Taylor Street
# Otay Mesa Rd becomes Otay Mesa Road
# J St becomes J Street
# Judicial Dr becomes Judicial Drive
# Jamacha Rd becomes Jamacha Road
# Gullstrand St becomes Gullstrand Street
# Girard Ave becomes Girard Avenue
# Woodside Ave becomes Woodside Avenue
# Village Pl becomes Village Place
# Adams Ave becomes Adams Avenue
# Garnet Ave becomes Garnet Avenue
# Garnet Ave becomes Garnet Avenue
# Balboa Ave becomes Balboa Avenue
# Pavlov Av becomes Pavlov Avenue
# Sunset Ln becomes Sunset Lane
# Brabham St becomes Brabham Street
# Summit Av becomes Summit Avenue
# Cottonwood Av becomes Cottonwood Avenue
# Ash St becomes Ash Street
# B St becomes B Street
# Kearny Villa Rd becomes Kearny Villa Road
# Scranton Rd becomes Scranton Road
# Cuyamaca St becomes Cuyamaca Street
# La Jolla Village Dr becomes La Jolla Village Drive
# Royal Rd becomes Royal Road
# Hancock St becomes Hancock Street
# Piper St becomes Piper Street
# Piper St becomes Piper Street
# Piper St becomes Piper Street
# Piper St becomes Piper Street
# Piper St becomes Piper Street
# Chicago St becomes Chicago Street
# Chicago St becomes Chicago Street
# Chicago St becomes Chicago Street
# Chicago St becomes Chicago Street
# Chicago St becomes Chicago Street
# Chicago St becomes Chicago Street
# Chicago St becomes Chicago Street
# Chicago St becomes Chicago Street
# Chicago St becomes Chicago Street
# Mactibby St becomes Mactibby Street
# Chicago St becomes Chicago Street
# Baker St becomes Baker Street
# Baker St becomes Baker Street
# Baker St becomes Baker Street
# Baker St becomes Baker Street
# Baker St becomes Baker Street
# Sumter St becomes Sumter Street
# Shawnee Rd becomes Shawnee Road
# Shawnee Rd becomes Shawnee Road
# Aeronca Av becomes Aeronca Avenue
# Crete St becomes Crete Street
# Crete St becomes Crete Street
# Mactibby St becomes Mactibby Street
# Chicago St becomes Chicago Street
# Chicago St becomes Chicago Street
# Chicago St becomes Chicago Street
# Prospect St becomes Prospect Street
# 10th Av becomes 10th Avenue
# S 38th St becomes S 38th Street
# Boston Av becomes Boston Avenue
# Mission Gorge Rd becomes Mission Gorge Road
# Jackman St becomes Jackman Street
# N Marshall Av becomes N Marshall Avenue
# Piper St becomes Piper Street
# Piper St becomes Piper Street
# Piper St becomes Piper Street
# N 2nd St becomes N 2nd Street
# Industrial Ln becomes Industrial Lane
# Akard St becomes Akard Street
# Woodside Av becomes Woodside Avenue
# Woodside Av becomes Woodside Avenue
# Woodside Av becomes Woodside Avenue
# Woodside Av becomes Woodside Avenue
# Woodside Av becomes Woodside Avenue
# Woodside Av becomes Woodside Avenue
# Woodside Av becomes Woodside Avenue
# Woodside Av becomes Woodside Avenue
# Woodside Av becomes Woodside Avenue
# Woodside Av becomes Woodside Avenue
# E Madison Av becomes E Madison Avenue
# Midway Dr becomes Midway Drive
# Midway Dr becomes Midway Drive
# Midway Dr becomes Midway Drive
# N Johnson Av becomes N Johnson Avenue
# N Johnson Av becomes N Johnson Avenue
# N Johnson Av becomes N Johnson Avenue
# North Harbor Dr becomes North Harbor Drive
# Bayfront Ct becomes Bayfront Court
#
# 4/7 Cleaning phone data
# 8584530631 becomes 858-453-0631
# 6192916443 becomes 619-291-6443
# 6192323242 becomes 619-232-3242
# 6192918287 becomes 619-291-8287
# 6192642072 becomes 619-264-2072
# 6197027160 becomes 619-702-7160
# 6195820136 becomes 619-582-0136
# 6192848730 becomes 619-284-8730
# 6194224141 becomes 619-422-4141
# 6192324737 becomes 619-232-4737
# 6196868700 becomes 619-686-8700
# 8584990202 becomes 858-499-0202
# 6194226414 becomes 619-422-6414
# 6194206040 becomes 619-420-6040
# 6194480899 becomes 619-448-0899
# 8584881191 becomes 858-488-1191
# 6192947483 becomes 619-294-7483
# 6196924910 becomes 619-692-4910
# 6194759880 becomes 619-475-9880
# 6192323101 becomes 619-232-3101
# 8584543541 becomes 858-454-3541
# 6192327931 becomes 619-232-7931
# 8584543541 becomes 858-454-3541
# 8584544244 becomes 858-454-4244
# 6194202300 becomes 619-420-2300
# 6192809944 becomes 619-280-9944
# 6194380806 becomes 619-438-0806
# 8585519510 becomes 858-551-9510
# 6196218230 becomes 619-621-8230
# 8586424117 becomes 858-642-4117
# 8557909903 becomes 855-790-9903
# 6192659701 becomes 619-265-9701
# 3109227166 becomes 310-922-7166
# 6192888989 becomes 619-288-8989
# 6197964735 becomes 619-796-4735
# 6194631615 becomes 619-463-1615
# 6192347703 becomes 619-234-7703
# 8887066940 becomes 888-706-6940
# 6197952463 becomes 619-795-2463
# 8586933500 becomes 858-693-3500
# 8664638553 becomes 866-463-8553
# 6192813089 becomes 619-281-3089
# 6192559040 becomes 619-255-9040
# 6192243621 becomes 619-224-3621
# 6192268000 becomes 619-226-8000
# 8584562240 becomes 858-456-2240
# 6193380500 becomes 619-338-0500
# 6192608024 becomes 619-260-8024
# 8776370450 becomes 877-637-0450
# 6192093554 becomes 619-209-3554
# 8584331426 becomes 858-433-1426
# 6196921652 becomes 619-692-1652
# 6192556475 becomes 619-255-6475
# 6192558940 becomes 619-255-8940
# 6192224704 becomes 619-222-4704
# 6192984646 becomes 619-298-4646
# 6192319680 becomes 619-231-9680
# 6194763763 becomes 619-476-3763
# 6195963212 becomes 619-596-3212
# 6196452864 becomes 619-645-2864
# 6196886109 becomes 619-688-6109
# 6196880170 becomes 619-688-0170
# 8584539383 becomes 858-453-9383
# 8585589555 becomes 858-558-9555
# 8584581388 becomes 858-458-1388
# 6192820437 becomes 619-282-0437
# 6195782600 becomes 619-578-2600
# 8586229070 becomes 858-622-9070
# 8584041395 becomes 858-404-1395
# 6196960199 becomes 619-696-0199
# 8888266893 becomes 888-826-6893
# 8584598271 becomes 858-459-8271
# 8584539383 becomes 858-453-9383
# 8584520661 becomes 858-452-0661
# 8584581388 becomes 858-458-1388
# 6192390003 becomes 619-239-0003
# 6197250850 becomes 619-725-0850
# 6192720022 becomes 619-272-0022
# 6194521462 becomes 619-452-1462
# 6192384567 becomes 619-238-4567
# 6192347703 becomes 619-234-7703
# 6192340425 becomes 619-234-0425
# 6193251900 becomes 619-325-1900
# 6197274867 becomes 619-727-4867
# 6192301485 becomes 619-230-1485
# 6197959657 becomes 619-795-9657
# 6192328850 becomes 619-232-8850
# 6192910202 becomes 619-291-0202
# 6192827283 becomes 619-282-7283
# 6192554100 becomes 619-255-4100
# 6195439952 becomes 619-543-9952
# 6195620774 becomes 619-562-0774
# 8584040701 becomes 858-404-0701
# 6195849712 becomes 619-584-9712
# 6195421987 becomes 619-542-1987
# 6192916565 becomes 619-291-6565
# 8585651288 becomes 858-565-1288
# 8584998963 becomes 858-499-8963
# 8584929333 becomes 858-492-9333
# 8585767466 becomes 858-576-7466
# 8585036888 becomes 858-503-6888
# 6198508624 becomes 619-850-8624
# 6192341088 becomes 619-234-1088
# 8588225268 becomes 858-822-5268
# 6195749596 becomes 619-574-9596
# 6192805501 becomes 619-280-5501
# 7605332937 becomes 760-533-2937
# 8006334029 becomes 800-633-4029
# 6197861024 becomes 619-786-1024
# 6197861024 becomes 619-786-1024
# 6195441000 becomes 619-544-1000
# 8583815595 becomes 858-381-5595
# 6195611692 becomes 619-561-1692
# 6195251531 becomes 619-525-1531
# 8582683821 becomes 858-268-3821
# 8009733878 becomes 800-973-3878
# 6195123210 becomes 619-512-3210
# 6195939500 becomes 619-593-9500
# 6197346483 becomes 619-734-6483
# 8585600688 becomes 858-560-0688
# 6192942074 becomes 619-294-2074
# 8583814451 becomes 858-381-4451
# 6197021468 becomes 619-702-1468
# 8009916504 becomes 800-991-6504
# 6192962304 becomes 619-296-2304
# 8582101212 becomes 858-210-1212
# 6105017873 becomes 610-501-7873
# 6199290461 becomes 619-929-0461
# 6192376033 becomes 619-237-6033
# 6199290443 becomes 619-929-0443
# 6195190106 becomes 619-519-0106
# 6192259691 becomes 619-225-9691
# 6192553100 becomes 619-255-3100
# 6192999982 becomes 619-299-9982
# 6198663333 becomes 619-866-3333
# 7605800116 becomes 760-580-0116
# 6192958500 becomes 619-295-8500
# 6192817433 becomes 619-281-7433
# 6196701861 becomes 619-670-1861
# 6193932253 becomes 619-393-2253
# 6194475556 becomes 619-447-5556
# 6192916700 becomes 619-291-6700
# 6192234722 becomes 619-223-4722
# 6199557759 becomes 619-955-7759
# 6192360870 becomes 619-236-0870
# 8584880551 becomes 858-488-0551
# 8776370450 becomes 877-637-0450
# 8584599772 becomes 858-459-9772
# 6196921155 becomes 619-692-1155
# 6192371245 becomes 619-237-1245
# 8589741946 becomes 858-974-1946
# 8587520468 becomes 858-752-0468
# 6192138447 becomes 619-213-8447
# 6197566921 becomes 619-756-6921
# 8005181233 becomes 800-518-1233
# 6192691120 becomes 619-269-1120
# 6197548846 becomes 619-754-8846
# 6192340628 becomes 619-234-0628
# 6192978800 becomes 619-297-8800
# 8884647748 becomes 888-464-7748
# 8582771554 becomes 858-277-1554
# 6195821250 becomes 619-582-1250
# 6192912900 becomes 619-291-2900
# 6198145700 becomes 619-814-5700
# 6192289997 becomes 619-228-9997
# 6195310999 becomes 619-531-0999
# 6198318491 becomes 619-831-8491
# 8584547554 becomes 858-454-7554
# 6192220561 becomes 619-222-0561
# 6192243411 becomes 619-224-3411
# 6192241234 becomes 619-224-1234
# 6198310224 becomes 619-831-0224
# 8582786200 becomes 858-278-6200
# 8583611280 becomes 858-361-1280
# 8582743087 becomes 858-274-3087
# 8582742031 becomes 858-274-2031
# 8584882529 becomes 858-488-2529
# 6192221880 becomes 619-222-1880
# 8582797724 becomes 858-279-7724
# 6196773150 becomes 619-677-3150
# 6198310225 becomes 619-831-0225
# 6192371247 becomes 619-237-1247
# 6192344436 becomes 619-234-4436
# 6193440372 becomes 619-344-0372
# 8584306876 becomes 858-430-6876
# 8585654807 becomes 858-565-4807
# 6192454459 becomes 619-245-4459
# 8586229636 becomes 858-622-9636
# 8002574268 becomes 800-257-4268
# 6192947774 becomes 619-294-7774
# 6192200692 becomes 619-220-0692
# 6192354014 becomes 619-235-4014
# 6192338880 becomes 619-233-8880
# 8584886392 becomes 858-488-6392
# 8589991362 becomes 858-999-1362
# 6194879909 becomes 619-487-9909
# 6192222828 becomes 619-222-2828
# 6192580605 becomes 619-258-0605
# 6197976964 becomes 619-797-6964
# 6192231171 becomes 619-223-1171
# 8584124009 becomes 858-412-4009
# 6192244623 becomes 619-224-4623
# 6192346323 becomes 619-234-6323
# 6195220449 becomes 619-522-0449
# 6199081911 becomes 619-908-1911
# 8582014411 becomes 858-201-4411
# 8584573301 becomes 858-457-3301
# 6194970771 becomes 619-497-0771
# 6194608925 becomes 619-460-8925
# 6194371134 becomes 619-437-1134
# 6195937660 becomes 619-593-7660
# 6192313673 becomes 619-231-3673
# 6194497707 becomes 619-449-7707
# 6192324045 becomes 619-232-4045
# 6192652099 becomes 619-265-2099
# 8584831542 becomes 858-483-1542
# 6194357779 becomes 619-435-7779
# 6194443393 becomes 619-444-3393
# 8585813500 becomes 858-581-3500
# 6192226440 becomes 619-222-6440
# 8002574268 becomes 800-257-4268
# 6193351786 becomes 619-335-1786
# 6192934450 becomes 619-293-4450
# 6195532084 becomes 619-553-2084
# 6192321234 becomes 619-232-1234
# 6192395548 becomes 619-239-5548
# 6194794141 becomes 619-479-4141
# 8772688822 becomes 877-268-8822
# 8586279738 becomes 858-627-9738
# 6195464806 becomes 619-546-4806
# 8585690890 becomes 858-569-0890
# 8585343300 becomes 858-534-3300
# 8585144500 becomes 858-514-4500
# 6193881800 becomes 619-388-1800
# 6192559040 becomes 619-255-9040
# 6192224704 becomes 619-222-4704
# 6197041020 becomes 619-704-1020
# 8585349384 becomes 858-534-9384
# 8585604551 becomes 858-560-4551
# 8586506999 becomes 858-650-6999
# 8584548409 becomes 858-454-8409
# 6196871080 becomes 619-687-1080
# 8777322848 becomes 877-732-2848
# 8585349480 becomes 858-534-9480
# 6194507676 becomes 619-450-7676
# 6192555147 becomes 619-255-5147
# 6198146350 becomes 619-814-6350
# 6192227608 becomes 619-222-7608
# 8582722275 becomes 858-272-2275
# 6192289881 becomes 619-228-9881
# 6192210200 becomes 619-221-0200
# 6192314040 becomes 619-231-4040
# 8585343230 becomes 858-534-3230
# 8585514653 becomes 858-551-4653
# 6195326400 becomes 619-532-6400
# 6194870090 becomes 619-487-0090
# 6195611061 becomes 619-561-1061
# 6196154100 becomes 619-615-4100
# 6194484242 becomes 619-448-4242
# 6194378788 becomes 619-437-8788
# 6195945200 becomes 619-594-5200
# 6192669673 becomes 619-266-9673
# 6196453057 becomes 619-645-3057
# 6194280175 becomes 619-428-0175
# 8584674000 becomes 858-467-4000
# 6196562373 becomes 619-656-2373
# 8584575593 becomes 858-457-5593
# 8586587360 becomes 858-658-7360
# 6199564805 becomes 619-956-4805
# 6195701100 becomes 619-570-1100
# 6195754421 becomes 619-575-4421
# 6195754955 becomes 619-575-4955
# 8585719673 becomes 858-571-9673
# 6192328414 becomes 619-232-8414
# 6192997400 becomes 619-299-7400
# 8556803238 becomes 855-680-3238
# 6197957002 becomes 619-795-7002
# 6192639191 becomes 619-263-9191
# 6192396738 becomes 619-239-6738
# 8584880551 becomes 858-488-0551
# 6192323224 becomes 619-232-3224
# 6196616500 becomes 619-661-6500
# 6198493100 becomes 619-849-3100
# 6192238171 becomes 619-223-8171
# 6192100334 becomes 619-210-0334
# 6192100327 becomes 619-210-0327
# 6192100385 becomes 619-210-0385
# 8584537575 becomes 858-453-7575
# 6192195246 becomes 619-219-5246
# 8584836300 becomes 858-483-6300
#
# 5/7 Cleaning cuisine data
# burgers, mexican becomes ['burgers', 'mexican']
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# burger becomes burgers
# coffee_shop becomes coffee
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# vietnamese;japanese;vegetarian becomes ['vietnamese', 'japanese', 'vegetarian']
# coffee_shop becomes coffee
# burger becomes burgers
# burger;sandwich becomes burgers;sandwich
# burgers;sandwich becomes ['burgers', 'sandwich']
# burger becomes burgers
# coffee_shop becomes coffee
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# spanish;italian;baja becomes ['spanish', 'italian', 'baja']
# sushi, japanese, korean becomes ['sushi', 'japanese', 'korean']
# india becomes indian
# steak_house becomes steak
# coffee_shop becomes coffee
# burger becomes burgers
# steak_house becomes steak
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# steak_house becomes steak
# coffee_shop becomes coffee
# doughnut becomes donuts
# coffee_shop becomes coffee
# pretzel becomes pretzels
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# burger becomes burgers
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# french;sandwich becomes ['french', 'sandwich']
# greek;turkish becomes ['greek', 'turkish']
# pizza;sandwich becomes ['pizza', 'sandwich']
# italian;sandwich becomes ['italian', 'sandwich']
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# burger becomes burgers
# burger becomes burgers
# steak_house becomes steak
# burger becomes burgers
# steak_house becomes steak
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# burger becomes burgers
# coffee_shop becomes coffee
# burger becomes burgers
# burger becomes burgers
# chinese;japanese becomes ['chinese', 'japanese']
# burger becomes burgers
# coffee_shop becomes coffee
# burger becomes burgers
# burger becomes burgers
# coffee_shop becomes coffee
# burger becomes burgers
# Unicode becomes burgers,_pizza,_salads and mac n cheese.
# burgers,_pizza,_salads and mac n cheese. becomes ['burgers', 'pizza', 'salads and mac n cheese.']
# burger becomes burgers
# coffee_shop becomes coffee
# burger becomes burgers
# coffee_shop becomes coffee
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# coffee_shop becomes coffee
# burger becomes burgers
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# burger becomes burgers
# donuts becomes donuts
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# coffee_shop becomes coffee
# burger becomes burgers
# coffee_shop becomes coffee
# burger becomes burgers
# burger becomes burgers
# italian;pizza becomes ['italian', 'pizza']
# burger;breakfast becomes burgers;breakfast
# burgers;breakfast becomes ['burgers', 'breakfast']
# donut becomes donuts
# chicken;fish;fish_and_chips;pasta becomes ['chicken', 'fish', 'fish_and_chips', 'pasta']
# coffee_shop becomes coffee
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# doughnuts becomes donuts
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# steak_house becomes steak
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# sandwich;coffee becomes ['sandwich', 'coffee']
# burger becomes burgers
# burger becomes burgers
# burger becomes burgers
# hawaiian,_shaved_ice,_desserts becomes ['hawaiian', 'shaved_ice', 'desserts']
# burger becomes burgers
# burger becomes burgers
#
# 6/7 Cleaning fast food name data
# Wiener Schnitzel becomes Wienerschnitzel
# Wienerschnitzel becomes Wienerschnitzel
# Wienerschnitzel becomes Wienerschnitzel
# Z Pizza becomes Zpizza
# ZPizza becomes Zpizza
# Bombay Coast becomes Bombay Coast Indian Tandoor & Curry Express
# Bombay Coast Indian Tandoor & Curry Express becomes Bombay Coast Indian Tandoor & Curry Express
# Little Caesar's Pizza becomes Little Caesars
# Little Caesar's Pizza becomes Little Caesars
# Little Caesar's Pizza becomes Little Caesars
# Little Caesar's Pizza becomes Little Caesars
# Little Caesar's Pizza becomes Little Caesars
# Little Caesar's Pizza becomes Little Caesars
# Little Caesar's Pizza becomes Little Caesars
# Little Ceasars becomes Little Caesars
# Little Caesar's Pizza becomes Little Caesars
# Daphne's becomes Daphne's California Greek Restaurant
# Daphne's Greek Cafe becomes Daphne's California Greek Restaurant
# Daphne's becomes Daphne's California Greek Restaurant
# Daphne's California Greek becomes Daphne's California Greek Restaurant
# Carl's Jr. / The Green Burrito becomes Carl's Jr. / The Green Burrito
# Carls Jr. / Green Burrito becomes Carl's Jr. / The Green Burrito
# Wahoo's Fish Taco becomes Wahoo's Fish Taco
# Wahoo's Fish Tacos becomes Wahoo's Fish Taco
# Five Guys Burgers and Fries becomes Five Guys Burger and Fries
# Five Guys becomes Five Guys Burger and Fries
# Evolution Fast Food becomes Evolution Fast Food
# Evolution becomes Evolution Fast Food
# Roberto's Taco Shop becomes Roberto's Taco Shop
# Roberto's becomes Roberto's Taco Shop
# Papa Johns becomes Papa John's Pizza
# Papa Johns becomes Papa John's Pizza
# Papa Johns becomes Papa John's Pizza
# Papa Johns becomes Papa John's Pizza
# Papa Johns becomes Papa John's Pizza
# Papa Johns becomes Papa John's Pizza
# Papa Johns becomes Papa John's Pizza
# Papa Johns becomes Papa John's Pizza
# Papa Johns becomes Papa John's Pizza
# Papa Johns becomes Papa John's Pizza
# Papa Johns becomes Papa John's Pizza
# Papa Johns becomes Papa John's Pizza
# Papa John's Pizza becomes Papa John's Pizza
# In-N-Out Burger becomes In-N-Out Burger
# In-N-Out Burgers becomes In-N-Out Burger
# In-N-Out Burger becomes In-N-Out Burger
# In-N-Out Burger becomes In-N-Out Burger
# In-N-Out Burger becomes In-N-Out Burger
# In-N-Out Burger becomes In-N-Out Burger
# In-N-Out Burger becomes In-N-Out Burger
# In N Out Burger becomes In-N-Out Burger
# In-N-Out Burger becomes In-N-Out Burger
# In-N-Out Burger becomes In-N-Out Burger
# In-N-Out Burger becomes In-N-Out Burger
# Jersey Mike's Subs becomes Jersey Mike's Subs
# Jersey Mike's becomes Jersey Mike's Subs
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carl's Junior becomes Carl's Jr.
# Carl's Jr becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carl's Jr becomes Carl's Jr.
# Carl's Jr. becomes Carl's Jr.
# Carls Jr becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Carls Jr. becomes Carl's Jr.
# Chipotle becomes Chipotle Mexican Grill
# Chipotle Mexican Food becomes Chipotle Mexican Grill
# Chipotle Mexican Grill becomes Chipotle Mexican Grill
# Chipotle becomes Chipotle Mexican Grill
# Chipotle becomes Chipotle Mexican Grill
# Chipotle becomes Chipotle Mexican Grill
# Chipotle becomes Chipotle Mexican Grill
# Chipotle becomes Chipotle Mexican Grill
# Chipotle becomes Chipotle Mexican Grill
# Chipotle becomes Chipotle Mexican Grill
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway Sandwiches becomes Subway
# Subway becomes Subway
# Subway becomes Subway
# Subway becomes Subway
# Subway becomes Subway
# Subway Sandwiches becomes Subway
# Subway becomes Subway
# Subway becomes Subway
# Subway becomes Subway
# Subway becomes Subway
# Subway becomes Subway
# Subway becomes Subway
# Subway becomes Subway
# Subway becomes Subway
# Subway becomes Subway
# Subway becomes Subway
# Subway becomes Subway
# Subway becomes Subway
# Rubio's Costal Grill becomes Rubio's Coastal Grill
# Rubio's Baja Grill becomes Rubio's Coastal Grill
# Rubio's Baja Grill becomes Rubio's Coastal Grill
# Rubio's Baja Grill becomes Rubio's Coastal Grill
# Rubio's Baja Grill becomes Rubio's Coastal Grill
# Rubio's becomes Rubio's Coastal Grill
# Rubio's Baja Grill becomes Rubio's Coastal Grill
# Rubio's Baja Grill becomes Rubio's Coastal Grill
# Rubio's Baja Grill becomes Rubio's Coastal Grill
# Rubio's Baja Grill becomes Rubio's Coastal Grill
# Rubio's Baja Grill becomes Rubio's Coastal Grill
# Rubio's Baja Grill becomes Rubio's Coastal Grill
# Rubio's Baja Grill becomes Rubio's Coastal Grill
# Rubio's Mexican Grill becomes Rubio's Coastal Grill
# Rubio's Fresh Mexican Grill becomes Rubio's Coastal Grill
# Rubio's Baja Grill becomes Rubio's Coastal Grill
# Rubio's becomes Rubio's Coastal Grill
# Rubios becomes Rubio's Coastal Grill
# Rubio's Fresh Mexican Grill becomes Rubio's Coastal Grill
# Rubio's Baja Grill becomes Rubio's Coastal Grill
# Rubio's becomes Rubio's Coastal Grill
# Pick Up Stix becomes Pick Up Stix
# Pick Up Stix becomes Pick Up Stix
# Pick Up Stix becomes Pick Up Stix
# Pick Up Stix becomes Pick Up Stix
# Pick-up Stix becomes Pick Up Stix
# Arbys becomes Arby's
# Arbys becomes Arby's
# Arbys becomes Arby's
# Arby's becomes Arby's
# Arbys becomes Arby's
# Arbys becomes Arby's
# Arbys becomes Arby's
# Arbys becomes Arby's
# Arbys becomes Arby's
# Arby's becomes Arby's
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack In The Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
# Jack in the Box becomes Jack in the Box
#
# 7/7 Cleaning religion data
# All clean

# %%
def write_to_json(data, filename):
    with open(filename, 'w') as fp:
        json.dump(data, fp)

# %%
write_to_json(master, 'sd.json')
